# %%
import pandas as pd
import matplotlib.pyplot as plt

import pyodbc
import numpy as np

# %%
df = pd.read_csv('input/2023Jan1-2023Nov30AmznSalesReportR.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45981 entries, 0 to 45980
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date/time                 45981 non-null  object
#  1   settlement id             45981 non-null  int64
#  2   type                      45981 non-null  object
#  3   order id                  45609 non-null  object
#  4   sku                       33477 non-null  object
#  5   description               45981 non-null  object
#  6   quantity                  33325 non-null  float64
#  7   marketplace               33422 non-null  object
#  8   account type              45981 non-null  object
#  9   fulfillment               33100 non-null  object
#  10  order city                33094 non-null  object
#  11  order state               33054 non-null  object
#  12  order postal              33093 non-null  object
#  13  tax collection model      30232 non-null  object
#  14  product sales             45981 non-null  object
#  15  product sales tax         45981 non-null  float64
#  16  shipping credits          45981 non-null  float64
#  17  shipping credits tax      45981 non-null  float64
#  18  gift wrap credits         45981 non-null  float64
#  19  giftwrap credits tax      45981 non-null  float64
#  20  Regulatory Fee            45981 non-null  int64
#  21  Tax On Regulatory Fee     45981 non-null  int64
#  22  promotional rebates       45981 non-null  float64
#  23  promotional rebates tax   45981 non-null  int64
#  24  marketplace withheld tax  45981 non-null  float64
#  25  selling fees              45981 non-null  float64
#  26  fba fees                  45981 non-null  float64
#  27  other transaction fees    45981 non-null  float64
#  28  other                     45981 non-null  object
#  29  total                     45981 non-null  object
# dtypes: float64(11), int64(4), object(15)
# memory usage: 10.5+ MB

# %% [markdown]
# **Convert columns to numeric**

# %%
df['product sales']=df['product sales'].apply(lambda x: x.replace(',',''))
df['product sales'] = df['product sales'].astype(float)

# %%
df['other']=df['other'].apply(lambda x: x.replace(',',''))
df['other'] = df['other'].astype(float)

# %%
df['total']=df['total'].apply(lambda x: x.replace(',',''))
df['total'] = df['total'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45981 entries, 0 to 45980
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date/time                 45981 non-null  object
#  1   settlement id             45981 non-null  int64
#  2   type                      45981 non-null  object
#  3   order id                  45609 non-null  object
#  4   sku                       33477 non-null  object
#  5   description               45981 non-null  object
#  6   quantity                  33325 non-null  float64
#  7   marketplace               33422 non-null  object
#  8   account type              45981 non-null  object
#  9   fulfillment               33100 non-null  object
#  10  order city                33094 non-null  object
#  11  order state               33054 non-null  object
#  12  order postal              33093 non-null  object
#  13  tax collection model      30232 non-null  object
#  14  product sales             45981 non-null  float64
#  15  product sales tax         45981 non-null  float64
#  16  shipping credits          45981 non-null  float64
#  17  shipping credits tax      45981 non-null  float64
#  18  gift wrap credits         45981 non-null  float64
#  19  giftwrap credits tax      45981 non-null  float64
#  20  Regulatory Fee            45981 non-null  int64
#  21  Tax On Regulatory Fee     45981 non-null  int64
#  22  promotional rebates       45981 non-null  float64
#  23  promotional rebates tax   45981 non-null  int64
#  24  marketplace withheld tax  45981 non-null  float64
#  25  selling fees              45981 non-null  float64
#  26  fba fees                  45981 non-null  float64
#  27  other transaction fees    45981 non-null  float64
#  28  other                     45981 non-null  float64
#  29  total                     45981 non-null  float64
# dtypes: float64(14), int64(4), object(12)
# memory usage: 10.5+ MB

# %% [markdown]
# **Only orders with an Order Id (Drops various seperate fees(Service Fees, Adjustments, FBA Inv Fees))**

# %%
Oid = df.loc[~df['order id'].isnull()]
Oid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45609 entries, 0 to 45980
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date/time                 45609 non-null  object
#  1   settlement id             45609 non-null  int64
#  2   type                      45609 non-null  object
#  3   order id                  45609 non-null  object
#  4   sku                       33334 non-null  object
#  5   description               45609 non-null  object
#  6   quantity                  33182 non-null  float64
#  7   marketplace               33321 non-null  object
#  8   account type              45609 non-null  object
#  9   fulfillment               33100 non-null  object
#  10  order city                33094 non-null  object
#  11  order state               33054 non-null  object
#  12  order postal              33093 non-null  object
#  13  tax collection model      30232 non-null  object
#  14  product sales             45609 non-null  float64
#  15  product sales tax         45609 non-null  float64
#  16  shipping credits          45609 non-null  float64
#  17  shipping credits tax      45609 non-null  float64
#  18  gift wrap credits         45609 non-null  float64
#  19  giftwrap credits tax      45609 non-null  float64
#  20  Regulatory Fee            45609 non-null  int64
#  21  Tax On Regulatory Fee     45609 non-null  int64
#  22  promotional rebates       45609 non-null  float64
#  23  promotional rebates tax   45609 non-null  int64
#  24  marketplace withheld tax  45609 non-null  float64
#  25  selling fees              45609 non-null  float64
#  26  fba fees                  45609 non-null  float64
#  27  other transaction fees    45609 non-null  float64
#  28  other                     45609 non-null  float64
#  29  total                     45609 non-null  float64
# dtypes: float64(14), int64(4), object(12)
# memory usage: 10.8+ MB

# %% [markdown]
# **Select fulfillment**

# %% [markdown]
# All FBM 'Shipping Services' items get dropped as they dont have a fulfillment

# %%
fulfillment = 'Amazon'
fulfil = Oid.loc[Oid['fulfillment']==fulfillment]
fulfil
# Out:
#                           date/time  settlement id   type  \
# 16       Jan 1, 2023 8:13:26 PM PST    17143526261  Order
# 17      Jan 1, 2023 11:09:19 PM PST    17149362761  Order
# 19       Jan 2, 2023 1:35:02 AM PST    17149362761  Order
# 21       Jan 2, 2023 4:29:46 AM PST    17149362761  Order
# 22       Jan 2, 2023 4:53:50 AM PST    17149362761  Order
# ...                             ...            ...    ...
# 45976  Nov 30, 2023 11:38:44 PM PST    19201956281  Order
# 45977  Nov 30, 2023 11:38:44 PM PST    19201956281  Order
# 45978  Nov 30, 2023 11:41:29 PM PST    19201956281  Order
# 45979  Nov 30, 2023 11:54:36 PM PST    19201956281  Order
# 45980  Nov 30, 2023 11:56:12 PM PST    19201956281  Order
#
#                   order id           sku  \
# 16     113-0597596-1010624  794296966fba
# 17     114-1237401-5494660  073134801fba
# 19     112-8442762-2924213  806088471fba
# 21     114-6930593-8312219  806088455fba
# 22     112-8442762-2924213  806088476fba
# ...                    ...           ...
# 45976  111-1594656-8635414  806088489fba
# 45977  113-2626300-0465837  147512162fba
# 45978  114-4344818-4509042  261185195fba
# 45979  111-6046110-5737833  806088456fba
# 45980  113-3336543-1938607  806088474fba
#
#                                              description  quantity  \
# 16     Markal - 96966 Pro-Line HP High Performance Li...       1.0
# 17     PIP 34-800/XL MaxiFoam G-Tek Premium Nitrile F...       1.0
# 19     3M Xtract Cubitron II Net Disc 710W, 120+, 5 i...       1.0
# 21     3M Xtract Cubitron II Net Disc 710W, 80+, 6 in...       1.0
# 22     3M Xtract Cubitron II Net Disc 710W, 320+, 5 i...       1.0
# ...                                                  ...       ...
# 45976  3M Xtract Cubitron II Net Disc 710W, 220+, 3 i...       1.0
# 45977  Lufkin Shockforce G2 16-ft Nite Eye, Magnetic ...       1.0
# 45978  GEARWRENCH 3/8" 120XP Flex Head Electronic Tor...       1.0
# 45979  Cubitron 3M Xtract Net Disc 710W, 120+, 6 in, ...       1.0
# 45980  Cubitron 3M Xtract Net Disc 710W, 220+, 5 in, ...       1.0
#
#       marketplace     account type fulfillment  ... Regulatory Fee  \
# 16     amazon.com  Invoiced Orders      Amazon  ...              0
# 17     amazon.com  Standard Orders      Amazon  ...              0
# 19     amazon.com  Standard Orders      Amazon  ...              0
# 21     amazon.com  Standard Orders      Amazon  ...              0
# 22     amazon.com  Standard Orders      Amazon  ...              0
# ...           ...              ...         ...  ...            ...
# 45976  amazon.com  Standard Orders      Amazon  ...              0
# 45977  amazon.com  Standard Orders      Amazon  ...              0
# 45978  amazon.com  Standard Orders      Amazon  ...              0
# 45979  amazon.com  Standard Orders      Amazon  ...              0
# 45980  amazon.com  Standard Orders      Amazon  ...              0
#
#       Tax On Regulatory Fee promotional rebates promotional rebates tax  \
# 16                        0                0.00                       0
# 17                        0                0.00                       0
# 19                        0                0.00                       0
# 21                        0                0.00                       0
# 22                        0                0.00                       0
# ...                     ...                 ...                     ...
# 45976                     0                0.00                       0
# 45977                     0                0.00                       0
# 45978                     0               -8.56                       0
# 45979                     0                0.00                       0
# 45980                     0                0.00                       0
#
#        marketplace withheld tax  selling fees  fba fees  \
# 16                        -1.68         -4.20     -5.06
# 17                        -3.43         -7.35     -5.71
# 19                         0.00         -3.30     -5.06
# 21                        -1.51         -4.80     -5.71
# 22                         0.00         -3.30     -4.27
# ...                         ...           ...       ...
# 45976                     -1.51         -3.12     -4.16
# 45977                     -1.75         -3.74     -5.70
# 45978                    -13.19        -29.31    -11.99
# 45979                     -3.21         -4.70     -5.70
# 45980                     -1.62         -3.88     -4.54
#
#        other transaction fees  other   total
# 16                        0.0    0.0   18.73
# 17                        0.0    0.0   35.93
# 19                        0.0    0.0   13.63
# 21                        0.0    0.0   21.48
# 22                        0.0    0.0   14.42
# ...                       ...    ...     ...
# 45976                     0.0    0.0   13.49
# 45977                     0.0    0.0   15.50
# 45978                     0.0    0.0  154.12
# 45979                     0.0    0.0   20.96
# 45980                     0.0    0.0   17.46
#
# [19333 rows x 30 columns]

# %%
if fulfillment == 'Amazon':
    fulfil['sku']=fulfil['sku'].apply(lambda x: str(x)[:9])
    fulfil['sku'].apply(lambda x: len(x)).unique()
# Out:
# C:\Users\rrichesin\AppData\Local\Temp\ipykernel_18132\2346058503.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fulfil['sku']=fulfil['sku'].apply(lambda x: str(x)[:9])

# %% [markdown]
# **Read in Cost sheet**

# %%
ordCost = pd.read_excel('input/amznCostOrders.xlsx')

# %%
ordCost.iloc[:,7:25].sample(10)
# Out:
#        Order Suffix Warehouse          Customer PO Reference  Line Number  \
# 7252              0      901A  114-8143572-5945817       NaN            1
# 9540              0      901A  111-4695568-0359418       NaN            1
# 17339             0       201  114-0440079-3177031       NaN            1
# 2601              0      901A  113-8263025-0930635       NaN            1
# 5375              0       201  112-3286614-1214608       NaN            1
# 14218             0      901A  112-4422202-7814606       NaN            1
# 9695              0       201  113-2822441-7113028       NaN            1
# 22140             0      901A  114-6752833-3465834       NaN            1
# 14891             0      901A  114-6315075-2363415       NaN            3
# 33689             0      901A  112-2466607-2608202       NaN            1
#
#       Entered Date Shipped Date Invoice Date Transaction Type  \
# 7252    2023-03-20   2023-03-20   2023-03-20               SO
# 9540    2023-04-13   2023-04-13   2023-04-13               SO
# 17339   2023-07-18   2023-07-19   2023-07-19               SO
# 2601    2023-01-30   2023-01-30   2023-01-30               SO
# 5375    2023-03-01   2023-03-02   2023-03-02               SO
# 14218   2023-06-09   2023-06-09   2023-06-09               SO
# 9695    2023-04-14   2023-04-17   2023-04-17               SO
# 22140   2023-09-09   2023-09-09   2023-09-11               SO
# 14891   2023-06-15   2023-06-15   2023-06-15               SO
# 33689   2023-12-16   2023-12-16   2023-12-18               SO
#
#        Customer Product Number Product Number Stock, Special, Non-Stock  \
# 7252                       NaN      806088457                         s
# 9540                       NaN      806088471                         s
# 17339                      NaN      794296960                       NaN
# 2601                       NaN      806088473                         s
# 5375                       NaN      134014751                         s
# 14218                      NaN      806088472                         s
# 9695                       NaN      261180550                       NaN
# 22140                      NaN      806088471                         s
# 14891                      NaN      806088456                         s
# 33689                      NaN      806088456                         s
#
#                    Description       Description 2  Qty Shipped UOM  \
# 7252    6"XNH 710W 150+ XTRACT   CUBITRON NET DISC            1  CT
# 9540    5"XNH 710W 120+ XTRACT   CUBITRON NET DISC            1  CT
# 17339  96960 PRO-LINE HP WHITE        PAINT MARKER            1  BX
# 2601    5"XNH 710W 180+ XTRACT   CUBITRON NET DISC            6  CT
# 5375   DGR51 .5 HP RIGHT ANGLE         DIE GRINDER            1  EA
# 14218   5"XNH 710W 150+ XTRACT   CUBITRON NET DISC            3  CT
# 9695    80550 57PC 3/8" DR 6PT  SAE/MET SOCKET SET            1  EA
# 22140   5"XNH 710W 120+ XTRACT   CUBITRON NET DISC            1  CT
# 14891   6"XNH 710W 120+ XTRACT   CUBITRON NET DISC            1  CT
# 33689   6"XNH 710W 120+ XTRACT   CUBITRON NET DISC            1  CT
#
#        Unit Cost  Unit Sell Price
# 7252    21.17487            31.99
# 9540    11.58460            22.99
# 17339   15.48000            33.91
# 2601    11.46458            21.99
# 5375    75.17246           127.50
# 14218   11.70720            22.99
# 9695    53.20000           107.99
# 22140   11.69226            23.27
# 14891   19.26235            31.99
# 33689   21.24475            31.49

# %%
ordCost.rename(columns={'Product Number':'sku'}, inplace=True)
cost = ordCost[['sku', 'Unit Cost']]
cost.sample(5)
# Out:
#              sku  Unit Cost
# 9918   806088474   13.66894
# 32669  794261051   29.27784
# 22164  794296960   15.49848
# 7092   794261053   25.68000
# 10911  794296873   15.24000

# %% [markdown]
# **Drop returned orders from cost sheet**

# %%
cost = cost.loc[cost['Unit Cost']>0]
cost['sku'].nunique()
# Out:
# 239

# %% [markdown]
# **Groupby cost to get average cost per item (since cost changes over time and whse)**

# %%
cost_gb = pd.DataFrame(cost.groupby('sku')['Unit Cost'].mean().reset_index(),columns=['sku','Unit Cost'])

# %%
cost_gb['sku'] = cost_gb['sku'].astype(str)
cost_gb['sku'] = cost_gb['sku'].str.zfill(9)

# %%
cost_gb
# Out:
#            sku   Unit Cost
# 0    001205841    2.840000
# 1    014297675  314.145000
# 2    030424352  144.550000
# 3    032003400   36.163845
# 4    056200331   12.830440
# ..         ...         ...
# 234  986800331   27.443270
# 235  986800341   38.575200
# 236  986803410   22.723793
# 237  434-61053   70.748000
# 238  00082204C   98.550000
#
# [239 rows x 2 columns]

# %% [markdown]
# **Combine to add product costs to df**

# %%
both = fulfil.join(cost_gb.set_index('sku'), on='sku')

# %%
both.sample(5)
# Out:
#                           date/time  settlement id   type  \
# 8412   Feb 24, 2023 10:43:16 PM PST    17466329531  Order
# 14924   Apr 6, 2023 11:33:13 AM PDT    17719575561  Order
# 32079  Aug 22, 2023 10:37:18 PM PDT    18566954581  Order
# 39906  Oct 18, 2023 12:33:38 PM PDT    18928092041  Order
# 18024   Apr 30, 2023 1:59:00 AM PDT    17801558341  Order
#
#                   order id        sku  \
# 8412   114-6206679-3008254  794296961
# 14924  112-2217598-6606610  806088470
# 32079  114-5858085-7005012  806088471
# 39906  113-1279929-2511409  806088456
# 18024  113-2041866-0769027  806088470
#
#                                              description  quantity  \
# 8412   Markal 96961- Paint-Riter+ Oily Surface Liquid...       1.0
# 14924  3M Xtract Cubitron II Net Disc 710W, 80+, 5 in...       1.0
# 32079  Cubitron 3M Xtract Net Disc 710W, 120+, 5 in, ...       1.0
# 39906  Cubitron 3M Xtract Net Disc 710W, 120+, 6 in, ...       1.0
# 18024  3M Xtract Cubitron II Net Disc 710W, 80+, 5 in...       1.0
#
#       marketplace     account type fulfillment  ... Tax On Regulatory Fee  \
# 8412   amazon.com  Standard Orders      Amazon  ...                     0
# 14924  amazon.com  Standard Orders      Amazon  ...                     0
# 32079  amazon.com  Standard Orders      Amazon  ...                     0
# 39906  amazon.com  Standard Orders      Amazon  ...                     0
# 18024  amazon.com  Standard Orders      Amazon  ...                     0
#
#       promotional rebates promotional rebates tax marketplace withheld tax  \
# 8412                  0.0                       0                    -2.65
# 14924                 0.0                       0                     0.00
# 32079                 0.0                       0                    -1.35
# 39906                 0.0                       0                     0.00
# 18024                 0.0                       0                    -2.18
#
#        selling fees  fba fees  other transaction fees  other  total  Unit Cost
# 8412          -4.35     -5.03                     0.0    0.0  19.61  14.844840
# 14924         -3.45     -4.75                     0.0    0.0  14.79  12.170029
# 32079         -3.38     -4.75                     0.0    0.0  14.43  11.728623
# 39906          0.00     -5.70                     0.0    0.0  30.53  20.315975
# 18024         -3.45     -4.75                     0.0    0.0  14.79  12.170029
#
# [5 rows x 31 columns]

# %% [markdown]
# **Get total cost of goods per order**

# %%
both['Extended Cost'] = both['quantity'] * both['Unit Cost']
both.iloc[:,14:]
# Out:
#        product sales  product sales tax  shipping credits  \
# 16             27.99               1.68              0.00
# 17             48.99               3.43              0.00
# 19             21.99               0.00              0.00
# 21             31.99               1.51              0.00
# 22             21.99               0.00              0.00
# ...              ...                ...               ...
# 45976          20.77               1.51              0.00
# 45977          24.94               1.75              0.00
# 45978         195.42              13.19              8.56
# 45979          31.36               3.21              0.00
# 45980          25.88               1.62              0.00
#
#        shipping credits tax  gift wrap credits  giftwrap credits tax  \
# 16                      0.0                0.0                   0.0
# 17                      0.0                0.0                   0.0
# 19                      0.0                0.0                   0.0
# 21                      0.0                0.0                   0.0
# 22                      0.0                0.0                   0.0
# ...                     ...                ...                   ...
# 45976                   0.0                0.0                   0.0
# 45977                   0.0                0.0                   0.0
# 45978                   0.0                0.0                   0.0
# 45979                   0.0                0.0                   0.0
# 45980                   0.0                0.0                   0.0
#
#        Regulatory Fee  Tax On Regulatory Fee  promotional rebates  \
# 16                  0                      0                 0.00
# 17                  0                      0                 0.00
# 19                  0                      0                 0.00
# 21                  0                      0                 0.00
# 22                  0                      0                 0.00
# ...               ...                    ...                  ...
# 45976               0                      0                 0.00
# 45977               0                      0                 0.00
# 45978               0                      0                -8.56
# 45979               0                      0                 0.00
# 45980               0                      0                 0.00
#
#        promotional rebates tax  marketplace withheld tax  selling fees  \
# 16                           0                     -1.68         -4.20
# 17                           0                     -3.43         -7.35
# 19                           0                      0.00         -3.30
# 21                           0                     -1.51         -4.80
# 22                           0                      0.00         -3.30
# ...                        ...                       ...           ...
# 45976                        0                     -1.51         -3.12
# 45977                        0                     -1.75         -3.74
# 45978                        0                    -13.19        -29.31
# 45979                        0                     -3.21         -4.70
# 45980                        0                     -1.62         -3.88
#
#        fba fees  other transaction fees  other   total   Unit Cost  \
# 16        -5.06                     0.0    0.0   18.73   15.366171
# 17        -5.71                     0.0    0.0   35.93   30.322755
# 19        -5.06                     0.0    0.0   13.63   11.728623
# 21        -5.71                     0.0    0.0   21.48   19.302393
# 22        -4.27                     0.0    0.0   14.42   11.750324
# ...         ...                     ...    ...     ...         ...
# 45976     -4.16                     0.0    0.0   13.49    8.732157
# 45977     -5.70                     0.0    0.0   15.50   11.840000
# 45978    -11.99                     0.0    0.0  154.12  139.657733
# 45979     -5.70                     0.0    0.0   20.96   20.315975
# 45980     -4.54                     0.0    0.0   17.46   12.596021
#
#        Extended Cost
# 16         15.366171
# 17         30.322755
# 19         11.728623
# 21         19.302393
# 22         11.750324
# ...              ...
# 45976       8.732157
# 45977      11.840000
# 45978     139.657733
# 45979      20.315975
# 45980      12.596021
#
# [19333 rows x 18 columns]

# %% [markdown]
# **Get refund totals for fulfillment type**

# %%
refunds = df.loc[(df['fulfillment']==fulfillment) & (df['type']=='Refund')]

# %% [markdown]
# **Drop refunds from amzn file**

# %%
bothNoRefunds = both.loc[both['type']=='Order']

# %%
bothNoRefunds
# Out:
#                           date/time  settlement id   type  \
# 16       Jan 1, 2023 8:13:26 PM PST    17143526261  Order
# 17      Jan 1, 2023 11:09:19 PM PST    17149362761  Order
# 19       Jan 2, 2023 1:35:02 AM PST    17149362761  Order
# 21       Jan 2, 2023 4:29:46 AM PST    17149362761  Order
# 22       Jan 2, 2023 4:53:50 AM PST    17149362761  Order
# ...                             ...            ...    ...
# 45976  Nov 30, 2023 11:38:44 PM PST    19201956281  Order
# 45977  Nov 30, 2023 11:38:44 PM PST    19201956281  Order
# 45978  Nov 30, 2023 11:41:29 PM PST    19201956281  Order
# 45979  Nov 30, 2023 11:54:36 PM PST    19201956281  Order
# 45980  Nov 30, 2023 11:56:12 PM PST    19201956281  Order
#
#                   order id        sku  \
# 16     113-0597596-1010624  794296966
# 17     114-1237401-5494660  073134801
# 19     112-8442762-2924213  806088471
# 21     114-6930593-8312219  806088455
# 22     112-8442762-2924213  806088476
# ...                    ...        ...
# 45976  111-1594656-8635414  806088489
# 45977  113-2626300-0465837  147512162
# 45978  114-4344818-4509042  261185195
# 45979  111-6046110-5737833  806088456
# 45980  113-3336543-1938607  806088474
#
#                                              description  quantity  \
# 16     Markal - 96966 Pro-Line HP High Performance Li...       1.0
# 17     PIP 34-800/XL MaxiFoam G-Tek Premium Nitrile F...       1.0
# 19     3M Xtract Cubitron II Net Disc 710W, 120+, 5 i...       1.0
# 21     3M Xtract Cubitron II Net Disc 710W, 80+, 6 in...       1.0
# 22     3M Xtract Cubitron II Net Disc 710W, 320+, 5 i...       1.0
# ...                                                  ...       ...
# 45976  3M Xtract Cubitron II Net Disc 710W, 220+, 3 i...       1.0
# 45977  Lufkin Shockforce G2 16-ft Nite Eye, Magnetic ...       1.0
# 45978  GEARWRENCH 3/8" 120XP Flex Head Electronic Tor...       1.0
# 45979  Cubitron 3M Xtract Net Disc 710W, 120+, 6 in, ...       1.0
# 45980  Cubitron 3M Xtract Net Disc 710W, 220+, 5 in, ...       1.0
#
#       marketplace     account type fulfillment  ... promotional rebates  \
# 16     amazon.com  Invoiced Orders      Amazon  ...                0.00
# 17     amazon.com  Standard Orders      Amazon  ...                0.00
# 19     amazon.com  Standard Orders      Amazon  ...                0.00
# 21     amazon.com  Standard Orders      Amazon  ...                0.00
# 22     amazon.com  Standard Orders      Amazon  ...                0.00
# ...           ...              ...         ...  ...                 ...
# 45976  amazon.com  Standard Orders      Amazon  ...                0.00
# 45977  amazon.com  Standard Orders      Amazon  ...                0.00
# 45978  amazon.com  Standard Orders      Amazon  ...               -8.56
# 45979  amazon.com  Standard Orders      Amazon  ...                0.00
# 45980  amazon.com  Standard Orders      Amazon  ...                0.00
#
#       promotional rebates tax marketplace withheld tax selling fees  fba fees  \
# 16                          0                    -1.68        -4.20     -5.06
# 17                          0                    -3.43        -7.35     -5.71
# 19                          0                     0.00        -3.30     -5.06
# 21                          0                    -1.51        -4.80     -5.71
# 22                          0                     0.00        -3.30     -4.27
# ...                       ...                      ...          ...       ...
# 45976                       0                    -1.51        -3.12     -4.16
# 45977                       0                    -1.75        -3.74     -5.70
# 45978                       0                   -13.19       -29.31    -11.99
# 45979                       0                    -3.21        -4.70     -5.70
# 45980                       0                    -1.62        -3.88     -4.54
#
#        other transaction fees  other   total   Unit Cost  Extended Cost
# 16                        0.0    0.0   18.73   15.366171      15.366171
# 17                        0.0    0.0   35.93   30.322755      30.322755
# 19                        0.0    0.0   13.63   11.728623      11.728623
# 21                        0.0    0.0   21.48   19.302393      19.302393
# 22                        0.0    0.0   14.42   11.750324      11.750324
# ...                       ...    ...     ...         ...            ...
# 45976                     0.0    0.0   13.49    8.732157       8.732157
# 45977                     0.0    0.0   15.50   11.840000      11.840000
# 45978                     0.0    0.0  154.12  139.657733     139.657733
# 45979                     0.0    0.0   20.96   20.315975      20.315975
# 45980                     0.0    0.0   17.46   12.596021      12.596021
#
# [18970 rows x 32 columns]

# %%
bothNoRefunds['order id'].nunique()
# Out:
# 14791

# %% [markdown]
# # Sums

# %%
sums = bothNoRefunds.iloc[:,14:].sum()
sums = pd.DataFrame(sums, columns=['sum'])

# %% [markdown]
# **adding the additional fba(Adjustments, FBA Inv, FBA Refunds) or fbm (FBM Refunds, Shipping Services) specific fees**

# %%
if fulfillment == 'Amazon':
    sums.loc['Adjustments'] = df.loc[df['type']=='Adjustment'].iloc[:,14:].sum()['total']
    sums.loc['FBA Inventory Fees'] = df.loc[df['type']=='FBA Inventory Fee'].iloc[:,14:].sum()['total']
    sums.loc['Refunds'] = refunds.iloc[:,14:].sum()['total']
elif fulfillment == 'Seller':
    sums.loc['Shipping Services'] = df.loc[df['type']=='Shipping Services'].iloc[:,14:].sum()['total']
    sums.loc['Refunds'] = refunds.iloc[:,14:].sum()['total']

# %% [markdown]
# **Net profit**

# %%
sums.loc['total']['sum'] - sums.loc['Extended Cost']['sum']
# Out:
# 112318.1060856639

# %% [markdown]
# **Net profit less specific fees**

# %%
net = sums.loc['total']['sum'] - sums.loc['Extended Cost']['sum']
if fulfillment == 'Amazon':
    net2 = net + sums.loc['Adjustments']['sum'] + sums.loc['FBA Inventory Fees']['sum'] + sums.loc['Refunds']['sum']
    print(net + sums.loc['Adjustments']['sum'] + sums.loc['FBA Inventory Fees']['sum'] + sums.loc['Refunds']['sum'])
else:
    net2 = net + sums.loc['Shipping Services']['sum'] + sums.loc['Refunds']['sum']
    print(net + sums.loc['Shipping Services']['sum'] + sums.loc['Refunds']['sum'])
# Out:
# 93197.63608566391

# %% [markdown]
# **Adding net profit row**

# %%
sums.loc['Net Profit'] = net2

# %%
#sums

# %% [markdown]
# **Adds percentage of sales values**

# %%
sums['percentage of sales'] = sums['sum'].apply(lambda x: round(((x / sums.loc['product sales']) * 100),1))
sums
# Out:
#                                     sum  percentage of sales
# product sales             757939.160000                100.0
# product sales tax          48865.480000                  6.4
# shipping credits            7639.290000                  1.0
# shipping credits tax         109.520000                  0.0
# gift wrap credits             11.980000                  0.0
# giftwrap credits tax           0.250000                  0.0
# Regulatory Fee                 0.000000                  0.0
# Tax On Regulatory Fee          0.000000                  0.0
# promotional rebates        -5330.060000                 -0.7
# promotional rebates tax        0.000000                  0.0
# marketplace withheld tax  -48975.250000                 -6.5
# selling fees             -112330.860000                -14.8
# fba fees                 -105663.460000                -13.9
# other transaction fees         0.000000                  0.0
# other                          0.000000                  0.0
# total                     542266.050000                 71.5
# Unit Cost                 395759.751164                 52.2
# Extended Cost             429947.943914                 56.7
# Adjustments                 4656.050000                  0.6
# FBA Inventory Fees         -7906.760000                 -1.0
# Refunds                   -15869.760000                 -2.1
# Net Profit                 93197.636086                 12.3

# %%
#sums.to_excel('fbm2.xlsx')
